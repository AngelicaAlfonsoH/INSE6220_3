# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelicaAlfonsoH/INSE6220_3/blob/main/AngieINSE6220_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lab 01

# %%
#!pip install pycaret==2.3.6
from pycaret.utils import version
version()

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
import pandas as pd
plt.rcParams['figure.figsize'] = (7,5)

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

print("Pandas version: ", pd.__version__)
print("Seaborn version: ", sns.__version__)

#read cvs file into dataframe
df=pd.read_csv("Employee.csv")
df.head(25)
df.info()
print("Number of duplicated rows is: ", df.duplicated().sum())

df.head(10)
# Out:
# Pandas version:  1.3.5
# Seaborn version:  0.11.2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   int64
#  1   PaymentTier                4653 non-null   int64
#  2   Age                        4653 non-null   int64
#  3   Gender                     4653 non-null   int64
#  4   ExperienceInCurrentDomain  4653 non-null   int64
#  5   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(6)
# memory usage: 218.2 KB
# Number of duplicated rows is:  3659
#    Education  PaymentTier  Age  Gender  ExperienceInCurrentDomain  LeaveOrNot
# 0          1            3   34       0                          0           0
# 1          1            1   28       1                          3           1
# ...

# %%
print("Number of duplicated rows is: ", df.duplicated().sum())
print("Number of rows with NaNs is: ", df.isna().any(axis=1).sum())
sns.pairplot(df, hue='Gender')
plt.show()
# Out:
# Number of duplicated rows is:  3659
# Number of rows with NaNs is:  0
